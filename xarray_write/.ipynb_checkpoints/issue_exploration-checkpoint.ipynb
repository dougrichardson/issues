# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load individual files

# %%
feb = xr.open_dataset('/g/data/xv83/dr6273/work/richardson_scratch/issues/xarray_write/2t_era5_moda_sfc_20190201-20190228.nc')
feb = feb.sel(latitude=slice(21,19), longitude=slice(79,80))

# %%
may = xr.open_dataset('/g/data/xv83/dr6273/work/richardson_scratch/issues/xarray_write/2t_era5_moda_sfc_20190501-20190531.nc')
may = may.sel(latitude=slice(21,19), longitude=slice(79,80))

# %% [markdown]
# ### What we expect:

# %%
may.t2m.plot()

# %% [markdown]
# ### Concat files

# %%
ds = xr.concat([feb, m], 'time')

# %%
ds.t2m.sel(time='2019-05').plot()

# %% [markdown]
# ### Write, read and plot

# %%
ds.to_netcdf('./test.nc', mode='w')
ds.close()

ds2 = xr.open_dataset('./test.nc')
ds2.t2m.sel(time='2019-05-01').plot()
ds2.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /g/data/xv83/dr6273/apps/envs/pangeo/lib/python3.9/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# /g/data/xv83/dr6273/apps/envs/pangeo/lib/python3.9/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/g/data/xv83/dr6273/work/richardson_scratch/issues/xarray_write/test.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
np.isclose(m.t2m.values, ds2.sel(time='2019-05').t2m.values)
# Out:
# array([[[False, False, False, False, False],
#         [False, False, False, False, False],
#         [False, False, False, False,  True],
#         [False, False, False, False, False],
#         [False, False, False, False, False],
#         [False, False, False, False, False],
#         [False, False, False, False, False],
#         [ True,  True, False, False, False],
#         [False,  True,  True,  True, False]]])

# %% [markdown]
# ### With encoding

# %%
ds.to_netcdf('./test_encoding.nc', mode='w', encoding={'t2m': {'dtype': 'float32'}})
ds3 = xr.open_dataset('./test_encoding.nc')
ds3.t2m.sel(time='2019-05-01').plot()
ds3.close()

# %%
np.isclose(m.t2m.values, ds3.sel(time='2019-05').t2m.values)
# Out:
# array([[[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True]]])

# %% [markdown]
# ### Dimension check

# %%
import numpy as np

# %%
np.sum(f.latitude.values != m.latitude.values)
# Out:
# 0

# %%
np.sum(f.longitude.values != m.longitude.values)
# Out:
# 0

# %%
f.coords
# Out:
# Coordinates:
#   * longitude  (longitude) float32 79.0 79.25 79.5 79.75 80.0
#   * latitude   (latitude) float32 21.0 20.75 20.5 20.25 ... 19.5 19.25 19.0
#   * time       (time) datetime64[ns] 2019-02-01

# %%
m.coords
# Out:
# Coordinates:
#   * longitude  (longitude) float32 79.0 79.25 79.5 79.75 80.0
#   * latitude   (latitude) float32 21.0 20.75 20.5 20.25 ... 19.5 19.25 19.0
#   * time       (time) datetime64[ns] 2019-05-01

# %%
print(m.t2m.values)
# Out:
# [[[310.66833 310.7832  310.8107  310.55347 310.12802]
#   [311.19247 311.03394 310.99835 310.856   310.30112]
#   [311.57587 311.09866 310.84628 310.272   309.6702 ]
#   [311.77808 311.25073 310.66187 310.0876  310.13934]
#   [311.77972 311.31866 310.67966 310.90613 310.95953]
#   [311.35263 310.76056 311.14233 311.28146 310.8301 ]
#   [310.32214 310.58908 311.0938  311.10513 310.60364]
#   [309.76242 309.84814 310.61334 311.07114 310.87216]
#   [310.28494 309.91287 309.94522 309.90802 309.98404]]]

# %%
print(ds2.sel(time='2019-05').t2m.values)
# Out:
# [[[229.6611  229.77606 229.80325 229.54614 229.12094]
#   [230.1852  230.02574 229.99113 229.84898 229.29398]
#   [230.56839 230.09125 229.8391  229.26431 309.66995]
#   [230.76987 230.24329 229.65369 229.08014 229.13205]
#   [230.77234 230.31128 229.67223 229.89842 229.95157]
#   [230.34465 229.75256 230.13452 230.2742  229.82303]
#   [229.315   229.58199 230.0863  230.09744 229.59558]
#   [309.76266 309.84796 229.60547 230.06406 229.86505]
#   [229.27792 309.91348 309.94562 309.9085  228.97632]]]

# %%
xr.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.9.4 | packaged by conda-forge | (default, May 10 2021, 22:13:33)
# [GCC 9.3.0]
# python-bits: 64
# OS: Linux
# OS-release: 4.18.0-305.7.1.el8.nci.x86_64
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: ('en_US', 'UTF-8')
# libhdf5: 1.10.6
# libnetcdf: 4.7.4
#
# xarray: 0.19.0
# pandas: 1.2.4
# numpy: 1.20.3
# scipy: 1.6.3
# netCDF4: 1.5.6
# pydap: None
# h5netcdf: None
# h5py: None
# Nio: None
# zarr: 2.8.3
# cftime: 1.5.0
# nc_time_axis: 1.2.0
# PseudoNetCDF: None
# rasterio: 1.2.4
# cfgrib: None
# iris: None
# bottleneck: 1.3.2
# dask: 2021.05.1
# distributed: 2021.05.1
# matplotlib: 3.4.2
# cartopy: 0.19.0.post1
# seaborn: None
# numbagg: None
# pint: None
# setuptools: 49.6.0.post20210108
# pip: 21.1.2
# conda: 4.10.1
# pytest: None
# IPython: 7.24.0
# sphinx: None

# %%
# client.close()
# cluster.close()
